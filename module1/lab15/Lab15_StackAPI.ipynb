# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
pip install stackapi
# Out:
# ...
#   Created wheel for stackapi: filename=StackAPI-0.2.0-py3-none-any.whl size=5858 sha256=57b1e22129b90cf5d5a167661c676b4c3207ffcfe8bf35d1c252cd02624328d4
#   Stored in directory: /Users/manele/Library/Caches/pip/wheels/de/58/fe/8bab7cf44d8b0bf32e46f1715df2ba8c97d475de95a20985ac
# Successfully built stackapi
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from stackapi import StackAPI
import requests
import json

# %%
SITE = StackAPI('stackoverflow')

questions = SITE.fetch('questions', fromdate='2022-06-01', todate='2022-07-01')
questions
question=[q["title"] for q in questions["items"]]
question
question_id=[q["question_id"] for q in questions["items"]]
question_id
# Out:
# [72510970,
#  72794658,
#  72819606,
#  72565069,
#  72789709,
#  72743336,
#  72768245,
#  72560318,
#  72607126,
#  72657781,
#  72495760,
#  72706523,
#  72747070,
#  72485735,
#  72613089,
#  72526429,
#  72585961,
#  72484501,
#  72679043,
#  72613532,
#  72586951,
#  72618814,
#  72535879,
#  72618793,
#  72788135,
#  72632118,
#  72498160,
#  72732871,
#  72589691,
#  72654553,
#  72733293,
#  72488915,
#  72787925,
#  72762257,
#  72495612,
#  72788223,
#  72527461,
#  72781164,
#  72551293,
#  72801402,
#  72721223,
#  72556334,
#  72617913,
#  72460618,
#  72532647,
#  72667963,
#  72477816,
#  72659387,
#  72799209,
#  72612734,
#  72546678,
#  72783510,
#  72800515,
#  72772688,
#  72781162,
#  72751492,
#  72458394,
#  72595196,
#  72795311,
#  72710425,
#  72556583,
#  72640891,
#  72686417,
#  72808316,
#  72801446,
#  72812937,
#  72536114,
#  72735338,
#  72468880,
#  72460927,
#  72577624,
#  72645277,
#  72563028,
#  72633230,
#  72507099,
#  72561109,
# ...

# %%
answers = SITE.fetch('questions/{ids}/answers', ids=question_id[:100], filter='withbody')
answer = [a['body'] for a in answers ['items']]
answer
# Out:
# ['<p>@Barmar\'s answer is probably the correct for this particular question. If you have more than just 4 jobs you want to run in parallel, a better solution is to use <code>parset</code>:</p>\n<pre><code>$ parset myarr -j 8 \'echo Job {#}; echo arguments {}\' ::: a b c ::: X Y Z ::: 1 2 3\n$ echo ${myarr[5]}\nJob 6 arguments a Y 3\n</code></pre>\n<p><code>parset</code> will basically do what @Barmar does, but will also clean up tmp-files if the command crashes.</p>\n<p><a href="https://www.gnu.org/software/parallel/parset.html" rel="nofollow noreferrer">https://www.gnu.org/software/parallel/parset.html</a></p>\n',
#  '<p>If the versions of your Harbor instances are the same, you can try to replicate your data over to your k8s Harbor instance. See <a href="https://goharbor.io/docs/2.5.0/administration/configuring-replication/" rel="nofollow noreferrer">docs</a> for more info. Member information is not replicated.</p>\n',
# ...

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
response=requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")
print(response.json())
# Out:
# {'items': [{'tags': ['python', 'pandas', 'datetime', 'timedelta'], 'owner': {'account_id': 26205797, 'reputation': 1, 'user_id': 19885406, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmn_nAAIG_K7wrYZsalTlpIDH9hS6Fax5ZMdeSHE=k-s256', 'display_name': 'Oilyfingers99', 'link': 'https://stackoverflow.com/users/19885406/oilyfingers99'}, 'is_answered': False, 'view_count': 21, 'answer_count': 1, 'score': 0, 'last_activity_date': 1661935086, 'creation_date': 1661934211, 'question_id': 73552912, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73552912/python-pandas-time-delta-to-timestamp', 'title': 'Python pandas time delta to timestamp'}, {'tags': ['mvvm', 'observablecollection', 'maui'], 'owner': {'account_id': 24273905, 'reputation': 1, 'user_id': 18221485, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/1f1a7fc8af8f728d10e0b8bea3af25f2?s=256&d=identicon&r=PG', 'display_name': 'GordonR', 
# ...

# %%
results=(response.json())
res=response.json()
l=res["items"]
l
# Out:
# [{'tags': ['python', 'pandas', 'datetime', 'timedelta'],
#   'owner': {'account_id': 26205797,
#    'reputation': 1,
#    'user_id': 19885406,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmn_nAAIG_K7wrYZsalTlpIDH9hS6Fax5ZMdeSHE=k-s256',
#    'display_name': 'Oilyfingers99',
#    'link': 'https://stackoverflow.com/users/19885406/oilyfingers99'},
#   'is_answered': False,
#   'view_count': 21,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661935086,
#   'creation_date': 1661934211,
#   'question_id': 73552912,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73552912/python-pandas-time-delta-to-timestamp',
#   'title': 'Python pandas time delta to timestamp'},
#  {'tags': ['mvvm', 'observablecollection', 'maui'],
#   'owner': {'account_id': 24273905,
#    'reputation': 1,
#    'user_id': 18221485,
#    'user_type': 'registered',
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
questions = SITE.fetch('questions', fromdate='2022-08-01', todate='2022-08-02',tag='python',score='5')
questions
question=[q["title"] for q in questions["items"]]
question
# Out:
# ['TriangleMesh Texture Coordinates are not interpolated as expected',
#  '2sxc - Content/Apps is not being imported',
#  'Did I set up tensorflow correctly (warning: so returning NUMA node zero)?',
#  'error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function &#39;rectangle&#39;',
#  'Google Analytics Internal Server Error 500',
#  'Is there a way to eliminate fatal error and unexpected error in PHP',
#  '&#39;_InvalidUnpickledPCollection&#39; object has no attribute &#39;windowing&#39;',
#  'Execute custom SQL before running FromSqlRaw in Entity Framework Core 6 or above in SQL Server',
#  'How can I add FormData with Html.BeginForm',
#  'how to count or get record of rows, whose primary_key is not in foreign table?',
#  'Vs code warnings in C',
#  'In a Excel file how to find the background color of a cell using openpyxl (Python)',
#  'Laravel. Difference between php artisan make:model and make:migration',
# ...

# %%
for i in results["items"]:
    if "python" in (i["tags"]):
        print(i["title"])
# Out:
# Python pandas time delta to timestamp
# Python: How to efficiently create all possible 2 element swaps of an array?

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
for i in results["items"]:
     if "question_id"=="6784" and "question_id"=="6473":
        print('True')
else:
        print("False")
# Out:
# False
