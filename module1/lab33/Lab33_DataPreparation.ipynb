# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/Users/manele/Downloads/example_data_cleaning.xlsx')

# %%
df
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0  2013.000000    12900.0      Student        78.0
# 1             2.0   34983.0  2015.000000     1230.0       barmen        78.0
# 2             3.0   34984.0  1945.000000     3450.0      student        78.0
# 3             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000     7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000    10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000    30090.0      Manager        78.0
# 7            22.0   34987.0          NaN    18990.0       sailer        78.0
# 8             7.0   34988.0          NaN    12330.0      Manager        78.0
# 9            23.0   34988.0  1999.000000    25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# ...

# %%
#Missing data, duplicates

# %%
df.sort_values(by='ClientID')
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0  2013.000000    12900.0      Student        78.0
# 1             2.0   34983.0  2015.000000     1230.0       barmen        78.0
# 2             3.0   34984.0  1945.000000     3450.0      student        78.0
# 3             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000     7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000    10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000    30090.0      Manager        78.0
# 7            22.0   34987.0          NaN    18990.0       sailer        78.0
# 8             7.0   34988.0          NaN    12330.0      Manager        78.0
# 9            23.0   34988.0  1999.000000    25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# ...

# %%
values = {"BirthYear": 1967, "BirthYear": 1999}
df.fillna(value=values)
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0  2013.000000    12900.0      Student        78.0
# 1             2.0   34983.0  2015.000000     1230.0       barmen        78.0
# 2             3.0   34984.0  1945.000000     3450.0      student        78.0
# 3             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000     7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000    10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000    30090.0      Manager        78.0
# 7            22.0   34987.0  1999.000000    18990.0       sailer        78.0
# 8             7.0   34988.0  1999.000000    12330.0      Manager        78.0
# 9            23.0   34988.0  1999.000000    25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# ...

# %%
df['BirthYear'] = df['BirthYear'].fillna(0).astype(int)
print(df)
print(df.dtypes)
# Out:
#     TransactionID  ClientID  BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0       2013    12900.0      Student        78.0
# 1             2.0   34983.0       2015     1230.0       barmen        78.0
# 2             3.0   34984.0       1945     3450.0      student        78.0
# 3             4.0   34985.0       1923     5670.0      manager        78.0
# 4             5.0   34986.0       1978     7890.0           hr        78.0
# 5             6.0   34987.0       1967    10110.0      Manager        78.0
# 6            15.0   34987.0       1967    30090.0      Manager        78.0
# 7            22.0   34987.0          0    18990.0       sailer        78.0
# 8             7.0   34988.0          0    12330.0      Manager        78.0
# 9            23.0   34988.0       1999    25650.0      Manager        78.0
# 10            8.0   34989.0       1958    14550.0           HR        78.0
# ...

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0       2013    12900.0      Student        78.0
# 1             2.0   34983.0       2015     1230.0       barmen        78.0
# 2             3.0   34984.0       1945     3450.0      student        78.0
# 3             4.0   34985.0       1923     5670.0      manager        78.0
# 4             5.0   34986.0       1978     7890.0           hr        78.0
# 5             6.0   34987.0       1967    10110.0      Manager        78.0
# 6            15.0   34987.0       1967    30090.0      Manager        78.0
# 7            22.0   34987.0          0    18990.0       sailer        78.0
# 8             7.0   34988.0          0    12330.0      Manager        78.0
# 9            23.0   34988.0       1999    25650.0      Manager        78.0
# 10            8.0   34989.0       1958    14550.0           HR        78.0
# ...

# %%
df['BirthYear'] = df['BirthYear'].replace([0],[1967])

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0       2013    12900.0      Student        78.0
# 1             2.0   34983.0       2015     1230.0       barmen        78.0
# 2             3.0   34984.0       1945     3450.0      student        78.0
# 3             4.0   34985.0       1923     5670.0      manager        78.0
# 4             5.0   34986.0       1978     7890.0           hr        78.0
# 5             6.0   34987.0       1967    10110.0      Manager        78.0
# 6            15.0   34987.0       1967    30090.0      Manager        78.0
# 7            22.0   34987.0       1967    18990.0       sailer        78.0
# 8             7.0   34988.0       1967    12330.0      Manager        78.0
# 9            23.0   34988.0       1999    25650.0      Manager        78.0
# 10            8.0   34989.0       1958    14550.0           HR        78.0
# ...

# %%
df.at[7,'BirthYear']
# Out:
# 1967

# %%
df.at[7,'BirthYear']=1967

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0       2013    12900.0      Student        78.0
# 1             2.0   34983.0       2015     1230.0       barmen        78.0
# 2             3.0   34984.0       1945     3450.0      student        78.0
# 3             4.0   34985.0       1923     5670.0      manager        78.0
# 4             5.0   34986.0       1978     7890.0           hr        78.0
# 5             6.0   34987.0       1967    10110.0      Manager        78.0
# 6            15.0   34987.0       1967    30090.0      Manager        78.0
# 7            22.0   34987.0       1967    18990.0       sailer        78.0
# 8             7.0   34988.0       1967    12330.0      Manager        78.0
# 9            23.0   34988.0       1999    25650.0      Manager        78.0
# 10            8.0   34989.0       1958    14550.0           HR        78.0
# ...

# %%
df.fillna({'Profession':'bdm'}, inplace=True)

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0       2013    12900.0      student        78.0
# 1             2.0   34983.0       2015     1230.0       barmen        78.0
# 2             3.0   34984.0       1945     3450.0      student        78.0
# 3             4.0   34985.0       1923     5670.0      manager        78.0
# 4             5.0   34986.0       1978     7890.0           hr        78.0
# 5             6.0   34987.0       1967    10110.0      manager        78.0
# 6            15.0   34987.0       1967    30090.0      manager        78.0
# 7            22.0   34987.0       1967    18990.0       sailer        78.0
# 8             7.0   34988.0       1967    12330.0      manager        78.0
# 9            23.0   34988.0       1999    25650.0      manager        78.0
# 10            8.0   34989.0       1958    14550.0           hr        78.0
# ...

# %%
df.head()
# Out:
#    TransactionID  ClientID  BirthYear   Amount Profession  Department    Risk
# 0            1.0   34982.0       2013  12900.0    Student        78.0     Low
# 1            2.0   34983.0       2015   1230.0     barmen        78.0    High
# 2            3.0   34984.0       1945   3450.0    student        78.0  Medium
# 3            4.0   34985.0       1923   5670.0    manager        78.0     Low
# 4            5.0   34986.0       1978   7890.0         hr        78.0    High

# %%
def clean_initial(x):
    x = x.str.lower()
    return x

obj_profession = df.select_dtypes(include=['object']).columns

for item in obj_profession:
     df[item]=clean_initial(df[item])
df
# Out:
#     TransactionID  ClientID  BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0        NaN    12900.0      student        78.0
# 1             2.0   34983.0        NaN     1230.0       barmen        78.0
# 2             3.0   34984.0     1945.0     3450.0      student        78.0
# 3             4.0   34985.0     1923.0     5670.0      manager        78.0
# 4             5.0   34986.0     1978.0     7890.0           hr        78.0
# 5             6.0   34987.0     1967.0    10110.0      manager        78.0
# 6            15.0   34987.0     1967.0    30090.0      manager        78.0
# 7            22.0   34987.0     1967.0    18990.0       sailer        78.0
# 8             7.0   34988.0     1967.0    12330.0      manager        78.0
# 9            23.0   34988.0     1999.0    25650.0      manager        78.0
# 10            8.0   34989.0     1958.0    14550.0           hr        78.0
# ...

# %%
df['Profession'] = df['Profession'].str.lower()
df
# Out:
#     TransactionID  ClientID  BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0       2013    12900.0      student        78.0
# 1             2.0   34983.0       2015     1230.0       barmen        78.0
# 2             3.0   34984.0       1945     3450.0      student        78.0
# 3             4.0   34985.0       1923     5670.0      manager        78.0
# 4             5.0   34986.0       1978     7890.0           hr        78.0
# 5             6.0   34987.0       1967    10110.0      manager        78.0
# 6            15.0   34987.0       1967    30090.0      manager        78.0
# 7            22.0   34987.0       1967    18990.0       sailer        78.0
# 8             7.0   34988.0       1967    12330.0      manager        78.0
# 9            23.0   34988.0       1999    25650.0      manager        78.0
# 10            8.0   34989.0       1958    14550.0           hr        78.0
# ...

# %%
df.fillna({'Profession':'bdm'}, inplace=True)

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0       2013    12900.0      student        78.0
# 1             2.0   34983.0       2015     1230.0       barmen        78.0
# 2             3.0   34984.0       1945     3450.0      student        78.0
# 3             4.0   34985.0       1923     5670.0      manager        78.0
# 4             5.0   34986.0       1978     7890.0           hr        78.0
# 5             6.0   34987.0       1967    10110.0      manager        78.0
# 6            15.0   34987.0       1967    30090.0      manager        78.0
# 7            22.0   34987.0       1967    18990.0       sailer        78.0
# 8             7.0   34988.0       1967    12330.0      manager        78.0
# 9            23.0   34988.0       1999    25650.0      manager        78.0
# 10            8.0   34989.0       1958    14550.0           hr        78.0
# ...

# %%
df.isnull().sum()
# Out:
# TransactionID    0
# ClientID         0
# BirthYear        0
# Amount           0
# Profession       0
# Department       0
# Risk             0
# dtype: int64

# %%
df['Profession'] = df['Profession'].str.replace('etudient', 'student')
df['Profession'] = df['Profession'].str.replace('sailer', 'sailor')

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0       2013    12900.0      student        78.0
# 1             2.0   34983.0       2015     1230.0       barmen        78.0
# 2             3.0   34984.0       1945     3450.0      student        78.0
# 3             4.0   34985.0       1923     5670.0      manager        78.0
# 4             5.0   34986.0       1978     7890.0           hr        78.0
# 5             6.0   34987.0       1967    10110.0      manager        78.0
# 6            15.0   34987.0       1967    30090.0      manager        78.0
# 7            22.0   34987.0       1967    18990.0       sailor        78.0
# 8             7.0   34988.0       1967    12330.0      manager        78.0
# 9            23.0   34988.0       1999    25650.0      manager        78.0
# 10            8.0   34989.0       1958    14550.0           hr        78.0
# ...

# %%
import category_encoders as ce

# %%
encoder = ce.OneHotEncoder(cols=['Profession','Risk'])
encoder.fit(df)
df2 = encoder.transform(df)
df2
# Out:
#     TransactionID  ClientID  BirthYear     Amount  Profession_1  Profession_2  \
# 0             1.0   34982.0       2013    12900.0             1             0
# 1             2.0   34983.0       2015     1230.0             0             1
# 2             3.0   34984.0       1945     3450.0             1             0
# 3             4.0   34985.0       1923     5670.0             0             0
# 4             5.0   34986.0       1978     7890.0             0             0
# 5             6.0   34987.0       1967    10110.0             0             0
# 6            15.0   34987.0       1967    30090.0             0             0
# 7            22.0   34987.0       1967    18990.0             0             0
# 8             7.0   34988.0       1967    12330.0             0             0
# 9            23.0   34988.0       1999    25650.0             0             0
# 10            8.0   34989.0       1958    14550.0             0             0
# ...
