# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

plt.plot(x, x, label ='linear')
plt.plot(y, y*2, label ='')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Linear vs Non Linear Plots")
plt.legend()
plt.show()

# %%
# Method 1

plt.plot(x, z, label ='linear')
plt.plot(y, z**2, label ='')

plt.xlabel('x label')
plt.ylabel('z label')

plt.title("Linear vs Non Linear Plots")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
x = np.arange(0,100)
y = x*2

f, (ax1, ax2) = plt.subplots(1, 2, sharey = True)
ax1.plot(x, y)
ax1.set_title('Simple plot')
ax2.scatter(x, y)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

x = np.arange(0,100)
y = x*2

f, (ax1, ax2) = plt.subplots(1, 2,  gridspec_kw={'width_ratios':[10,10]}, sharey = True)
ax1.plot(x, y)
ax1.set_title('Simple plot')
ax2.scatter(x, y)

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# Method 2
x = np.arange(0,100)
y = np.exp(x)

plt.plot(x, y)

# %%
y = np.exp(x)
f, (ax1, ax2) = plt.subplots(1, 2)

ax1.set_title('Plot 1')
ax1.plot(x, np.exp(x))
ax2.set_title('Plot 2')

ax1.set_xscale('log')
ax1.set_yscale('log')

ax2.set_xscale('linear')
ax2.plot(x, np.exp(x))
ax2.set_yscale('linear')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 y = np.exp(x)
#       2 f, (ax1, ax2) = plt.subplots(1, 2)
#       4 ax1.set_title('Plot 1')
#
# NameError: name 'x' is not defined

# %%
y=np.exp(x)
figs,[ax1,ax2]=plt.subplots(1,2,figsize=(15, 15))
ax1.set_title('Normal scale')
ax1.plot(x,np.exp(x), color='r',label='exp x')
ax1.plot(x,z, color='green',label='x**2')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.legend()
ax2.set_xscale("linear")
ax2.set_yscale("linear")
ax2.set_title('logarithmic scale')
ax2.plot(x,np.exp(x), color='r',label='exp x')
ax2.plot(x,z, color='green',label='x**2')
ax2.set_xscale("log")
ax2.set_yscale("log")
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.legend()
# Out:
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# ...

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
import pandas as pd

fitbit = pd.read_csv(r'/Users/manele/IronHack/I2/DAFT_257/module_2/Lab_1_Matplotlib-and-Seaborn/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(12,4))
med_monthly_steps = fitbit.groupby('Months_encoded')['Steps'].median()

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(12,4))
med_monthly_steps = fitbit.groupby('Months_encoded')['Steps'].median()
x = pd.DataFrame(med_monthly_steps).reset_index()

ax1.plot(x['Months_encoded'], x['Steps'])
ax1.set_xlabel('Month')
ax1.set_ylabel('Median steps')
ax1.set_title('Median steps per month', fontsize=17)



# MEDIAN STEPS BY WORK_OR_WEEKEND

med_work_or_weekend = fitbit.groupby('Work_or_Weekend')['Steps'].median()
y = pd.DataFrame(med_work_or_weekend).reset_index()

ax2.plot(y['Work_or_Weekend'], y['Steps'])
ax2.set_xlabel('Work/Weekend')
ax2.set_ylabel('Median steps')
ax2.set_title('Median steps per work or weekday', fontsize=17)
# Out:
# Text(0.5, 1.0, 'Median steps per work or weekday')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
cols = ['Minutes Lightly Active', 'Minutes Very Active vs Steps', 'Minutes Sedentary vs Steps']
df = fitbit(cols)

f, ax = plt.subplots

for i in range (3):
    plt.ax[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 cols = ['Minutes Lightly Active', 'Minutes Very Active vs Steps', 'Minutes Sedentary vs Steps']
# ----> 2 df = fitbit(cols)
#       4 f, ax = plt.subplots
#       6 for i in range (3):
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv(r'/Users/manele/IronHack/I2/DAFT_257/module_2/Lab_1_Matplotlib-and-Seaborn/titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic = pd.DataFrame(titanic)
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include = 'int64')
# Out:
#       PassengerId  Pclass  SibSp  Parch
# 0               1       3      1      0
# 1               2       1      1      0
# 2               3       3      0      0
# 3               4       1      1      0
# 4               5       3      0      0
# ...           ...     ...    ...    ...
# 1304         1305       3      0      0
# 1305         1306       1      0      0
# 1306         1307       3      0      0
# 1307         1308       3      0      0
# 1308         1309       3      1      1
#
# [1309 rows x 4 columns]

# %%
titanic.select_dtypes(include = 'float64')
# Out:
#       Survived        Age      Fare
# 0          0.0  22.000000    7.2500
# 1          1.0  38.000000   71.2833
# 2          1.0  26.000000    7.9250
# 3          1.0  35.000000   53.1000
# 4          0.0  35.000000    8.0500
# ...        ...        ...       ...
# 1304       NaN  29.513190    8.0500
# 1305       NaN  39.000000  108.9000
# 1306       NaN  38.500000    7.2500
# 1307       NaN  29.513190    8.0500
# 1308       NaN  25.315435   22.3583
#
# [1309 rows x 3 columns]

# %%
# CATEGORICAL VARIABLES

titanic.select_dtypes(include = 'object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize=(12,6))
sns.barplot(data = titanic, x = 'Age', y = 'Survived')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic.Age.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.color_palette("flare", as_cmap=True)

# %%
sns.barplot(x = 'Age', data = titanic, y = 'Gender', palette = "flare");

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
titanic.Age.plot.hist(bins = [10, 20, 50])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.displot(titanic, x="Age", binwidth=3)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic.groupby('Gender')['Gender'].count().plot.bar(color = ['pink', 'blue'], edgecolor = 'red')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title("Gender of the passengers")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Method 2 - seaborn
# your code here

sns.set_style('darkgrid')
sns.histplot(x = "Gender", data=titanic, hue = "Gender",  palette=['tab:blue', 'tab:pink']);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.set_style('darkgrid')
sns.histplot(x = "Pclass", data=titanic, palette=['tab:blue', 'tab:pink']);

# %%
titanic.Pclass.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
ax = sns.boxplot(x=titanic["Age"])

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
That passengers on the Titanic were mostly between the ages of 20 and 40

"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
g = sns.JointGrid(data=titanic, x="Age")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
That most of the passengers were 20 years old and that a lot of
newborns were present."""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic.plot.scatter(x='Age', y='Fare', color = 'red')
plt.xlim(0)
plt.ylim(0)
# Out:
# (0.0, 600.0)

# %%
# Method 2 - seaborn
sns.regplot(x = "Fare", y = "Age", data = titanic)
plt.xlim(0)
plt.ylim(0)
# Out:
# (0.0, 100.0)

# %%
sns.lineplot(x = "Fare", y = "Age", data = titanic)
plt.xlim(0)
plt.ylim(0)
# Out:
# (0.0, 80.0)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
dataplot = sns.heatmap(titanic.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Number of Siblings/Spouses Aboard and Number of Parents/Children Aboard
But also Survived and Fare"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.histplot(x = "Age", data=titanic, hue = "Pclass",  multiple="stack");

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.histplot(x = "Age", data=titanic, hue = "Gender",  multiple="stack", palette=['tab:blue', 'tab:pink'] );
